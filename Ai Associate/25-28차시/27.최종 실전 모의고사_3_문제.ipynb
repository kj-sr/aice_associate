# %% [markdown]
# # ✈️ **AICE Associate 최종 실전 모의고사 3**

# %% [markdown]
# ## **여행 상품 추천 모델**
#
# **[비즈니스 시나리오]**
#
# > 당신은 여행 상품 추천 플랫폼 **'에듀-트래블'**의 데이터 분석가입니다. 회사는 사용자의 프로필, 행동 패턴, 예약 기록을 종합적으로 분석하여 개인에게 가장 적합한 **여행 테마를 추천하는 AI 모델**을 개발하고자 합니다. 이 모델을 통해 고객 만족도를 높이고, 개인화된 마케팅을 통해 예약 전환율을 높이는 것이 목표입니다.

# %% [markdown]
# **[데이터셋 소개]**
# * `traveler_profiles.csv`: 여행객의 인적 정보 및 여행 스타일 데이터
# * `traveler_booking_history.json`: 여행객의 과거 예약 기록 및 추천 테마 데이터
#
# **[컬럼 설명]**
# - **traveler_id**: 여행객 고유 식별자
# - **age**: 나이
# - **annual_income**: 연간 소득
# - **travel_style**: 선호 여행 스타일
# - **preferred_continent**: 선호 대륙
# - **last_login_date**: 마지막 로그인 날짜
# - **device_ppi**: 사용 기기 해상도
# - **activity_score**: 여행 시 활동성 점수
# - **avg_travel_duration**: 평균 여행 기간
# - **avg_companion_count**: 평균 동행자 수
# - **booking_channel**: 주 예약 채널
# - **support_inquiry_count**: 고객센터 문의 횟수
# - **recommended_theme: 추천된 여행 테마 <-- Target**

# %% [markdown]
# ---

# %% [markdown]
# ## **문제 1. 아래 지시사항에 따라 서로 다른 형식의 두 데이터 파일을 불러와 하나의 데이터프레임으로 통합하시오.**
# **(1) 데이터 로드**
# - `pandas` 라이브러리를 `pd` 별칭으로 임포트하시오.
# - `traveler_profiles.csv` 파일과 `traveler_booking_history.json` 파일을 각각 불러오시오.
#
# **(2) 데이터 병합**
# - 불러온 두 데이터프레임을 `traveler_id` 컬럼을 기준으로 병합(merge)하여 `df` 변수에 저장하시오.
#
# **(3) 문제 유형 판별**
# - 타겟 변수 데이터 형태를 보고, 이 문제의 유형이 '회귀', '이진분류', '다중분류' 중 무엇인지 판단하여 `답안01` 변수에 문자열로 저장하시오.

# %%
# 여기에 코드를 작성하세요.

# %% [markdown]
# ## **문제 2. 아래 지시사항에 따라 데이터의 기초 정보를 분석하시오.**
# **(1) 데이터 구조 및 타입 확인**
# - `info()` 메소드를 사용하여 `df`의 전체적인 구조와 컬럼별 데이터 타입, 결측치 유무를 출력하시오.
#
# **(2) 수치형 데이터 분석**
# - 수치형 데이터의 기술 통계량을 확인하시오.
# - 출력된 결과에서 **`age` 컬럼의 표준편차(std)** 값을 `답안02_1`에 저장하시오.
# - **`annual_income` 컬럼의 75% 백분위수(75%)** 값을 `답안02_2`에 저장하시오.
#
# **(3) 범주형 데이터 분석**
# - `travel_style` 컬럼에 대해 각 값의 개수를 확인하고, **가장 빈도가 높은(가장 많은) 여행 스타일**의 개수(count)를 `답안02_3`에 저장하시오.

# %%
# 여기에 코드를 작성하세요.

# %% [markdown]
# ## **문제 3. 아래 지시사항에 따라 특정 조건의 데이터를 추출하고 분석하시오.**
# - `preferred_continent`가 'Europe'이고, `travel_style`이 'Adventurous'인 여행객 데이터를 추출하시오.
# - 추출된 데이터에서, **연간 소득(`annual_income`)이 가장 높은 상위 5명**의 `traveler_id`와 `annual_income`을 출력하시오.

# %%
# 여기에 코드를 작성하세요.

# %% [markdown]
# ## **문제 4. 아래 지시사항에 따라 시각화를 통해 이상치를 확인하시오.**
# - `seaborn` 라이브러리를 `sns` 별칭으로 임포트하시오.
# - `sns.boxplot`을 사용하여 `annual_income` 컬럼의 데이터 분포를 시각화하고, 이상치(outlier)가 존재하는지 확인하시오.
# - 이상치가 존재하면 True, 존재하진 않으면 False를 `답안04`에 저장하시오.

# %%
# 여기에 코드를 작성하세요.

# %% [markdown]
# ## **문제 5. 아래 지시사항에 따라 결측치를 처리하고 데이터 타입을 변환하시오.**
# **(1) 결측치 처리**
# - 각 컬럼의 결측치 갯수를 출력하시오.
# - `age` 컬럼의 결측치는 `age` 컬럼의 **중앙값(median)**으로 채우시오.
# - `travel_style` 컬럼의 결측치는 가장 빈도가 높은 **최빈값(mode)**으로 채우시오.
# - 결측치가 없어진 것을 확인하시오.
#
# **(2) 데이터 타입 변환 및 결측치 처리**
# - `avg_companion_count` 컬럼에서 str.replace 함수를 사용하여 '모름' 값을  해당 컬럼의 **최빈값**으로 문자열 변환을 하시오.
#     - df[컬럼명].str.replace() 사용
# - 최종적으로 `avg_companion_count` 컬럼의 데이터 타입을 **정수(int)**로 변환하시오.
#     - df[컬럼명].astype('int')

# %%
# 여기에 코드를 작성하세요.

# %% [markdown]
# ## **문제 6. 아래 지시사항에 따라 파생변수를 생성하시오.**
# - `last_login_date` 컬럼을 `datetime` 형식으로 변환하시오.
# - 기준일을 '2025-09-01'로 설정하고, 이 날짜와 `last_login_date`의 차이를 계산하여 **`days_since_last_login`** (최근 로그인 후 경과일) 컬럼을 생성하시오.
# - 생성 후, 더 이상 필요 없는 `last_login_date`와 `traveler_id` 컬럼은 삭제하고, 결과는 `df_drop` 변수에 저장하시오.
#
#
# ```python
# # 예제 데이터 (문자열 날짜)
# order_df = pd.DataFrame({
#     'product_name': ['노트북', '키보드', '마우스'],
#     'order_date': ['2025-08-01', '2025-08-10', '2025-07-25']
# })
#
# # 문자열(object) -> 날짜 (datetime)으로 변환
# pd.to_datetime(order_df['order_date'])
#
# # 기준일 설정 및 경과일 계산
# (pd.to_datetime('2025-08-15') - order_df['order_date']).dt.days
#
# ```

# %%
# 여기에 코드를 작성하세요.

# %% [markdown]
# ## **문제 7. 아래 지시사항에 따라 이상치를 처리하시오.**
# - **문제 4**에서 확인한 `annual_income`의 이상치를 IQR(Interquartile Range) rule을 사용하여 처리합니다.
# - IQR의 1.5배를 초과하는 상위 이상치들은, 상위 경계값(Upper Bound)으로 대체(Capping)하시오.

# %%
# 여기에 코드를 작성하세요.

# %% [markdown]
# ## **문제 8. 아래 지시사항에 따라 타겟 변수와 피처(Feature)를 인코딩하시오.**
# **(1) 타겟 변수 라벨 인코딩**
# - `sklearn.preprocessing`의 **`LabelEncoder`**를 사용하여 타겟 변수인 `recommended_theme` 컬럼을 0, 1, 2와 같은 숫자 값으로 변환하시오.
#
# **(2) 피처(Feature) 라벨 인코딩 (순서형 변수)**
# - `travel_style` 컬럼은 ['Adventurous','Balanced','Relaxing']의 순서를 가지는 순서형 변수입니다. **`LabelEncoder`**를 사용하여 이 문자열 값들을 숫자로 변환하시오.
#
# **(3) 피처(Feature) 원-핫 인코딩 (명목형 변수)**
# - `preferred_continent`와 `booking_channel` 두 컬럼에 대해 원-핫 인코딩을 수행하고, 결과를 `df_final`에 저장하시오.
# - 이때, 생성된 컬럼들 간의 불필요한 상관관계를 방지하기 위해 **`drop_first=True`** 파라미터를 사용하여 각 변수의 첫 번째 카테고리에 대한 컬럼은 삭제하시오.

# %%
# 여기에 코드를 작성하세요.

# %% [markdown]
# ## **문제 9. 아래 지시사항에 따라 데이터셋을 분할하고 스케일링하시오.**
# **(1) 피처(X)와 타겟(y) 분리**
# - `recommended_theme` 컬럼은 `y` 변수에, 이를 제외한 나머지 모든 컬럼은 `X` 변수에 저장하시오.
#
# **(2) 학습/테스트 데이터 분할**
# - `train_test_split`을 7:3 비율, `random_state=42`로 사용하여 데이터를 분할하시오. 다중 분류이므로 `stratify=y` 옵션을 추가하시오.
# - `X_train`, `X_test`, `y_train`, `y_test` 변수에 각각 저장하시오.
#
# **(3) 피처 스케일링**
# - `StandardScaler`를 `X_train`에 피처 스케일링을 한 후 `X_train_scaled`에 저장하시오.
# - `X_test`에 피처 스케일링을 한 후 `X_test_scaled`에 저장하시오.

# %%
# 여기에 코드를 작성하세요.

# %% [markdown]
# ## **문제 10. 아래 지시사항에 따라 3가지 머신러닝 모델을 학습하고 최적 모델을 선정하시오.**
# - 문제 유형에 맞는 3가지 모델(DecisionTree(단일 나무), RandomForest(배깅), GradientBoosting(부스팅))을 학습시키시오.
# - 모든 모델은 결과의 재현성을 위해 **`random_state=42`**로 설정합니다.
# - `f1_score` (average='macro')를 기준으로 성능을 비교하고, 가장 성능이 좋은 모델의 이름과 점수를 각각 `답안10_1`, `답안10_2`에 저장하시오.(클래스 이름 그대로 사용)

# %%
# 여기에 코드를 작성하세요.

# %% [markdown]
# ## **문제 11. 아래 지시사항에 따라 변수 중요도를 분석하시오.**
# **(1) 변수 중요도 시각화**
# - **문제 10**에서 학습시킨 **최적의 모델**의 `feature_importances_`를 사용하여, 예측에 가장 큰 영향을 미친 상위 5개 변수를 막대그래프로 시각화하시오.
# - 가장 영향도가 높은 feature를 `답안11` 변수에 저장하시오.

# %%
# 여기에 코드를 작성하세요.

# %% [markdown]
# ---

# %% [markdown]
# ## **문제 12. 아래 지시사항에 따라 모델 성능을 종합적으로 평가하시오.**
#
# **(1) 종합 성능 평가**
# - **문제 10**에서 학습시킨 **최적의 모델**의 예측 결과에 대해 `classification_report`를 출력하여, Accuracy 외 Precision, Recall 등 종합적인 성능을 확인하시오.

# %%
# 여기에 코드를 작성하세요.

# %% [markdown]
# ---

# %% [markdown]
# ## **문제 13. 아래 지시사항에 따라 딥러닝 모델을 설계하고 학습하시오.**
#
# **(1) 모델 설계**
# - `tensorflow.keras`를 사용하여 아래 아키텍처대로 순차 모델을 만들고 `dl_model` 변수에 저장하시오.
#
# **(2) 모델 컴파일**
# - **정수 형태의 타겟 변수**를 사용하는 분류에 적합한 **손실 함수**와 `optimizer='adam'`, `metrics=['accuracy']`로 컴파일하시오.
#
# **(3) 기본 모델 학습**
# - `epochs=100`, `validation_data=(X_test_scaled, y_test)`로 설정하고,학습 과정은 `history_base` 변수에 저장하시오.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# 여기에 코드를 작성하세요.

# %% [markdown]
# ## **문제 14. 아래의 시각화 코드를 실행시키고 지문에 답하시오.**

# %%
#아래의 시각화 코드를 실행하여 결과를 분석하시오.
import matplotlib.pyplot as plt
plt.figure(figsize=(15,6))
plt.subplot(1,2,1)
plt.plot(history_base.history['loss'],label='train loss')
plt.plot(history_base.history['val_loss'],label='valid loss')
plt.title('Loss')
plt.xlabel('epochs')
plt.ylabel('loss')
plt.legend()

plt.subplot(1,2,2)
plt.plot(history_base.history['accuracy'],label='accuracy')
plt.plot(history_base.history['val_accuracy'],label='valid accuracy')
plt.title('Accuracy')
plt.xlabel('epochs')
plt.ylabel('accuracy')
plt.legend()

plt.show()

# %% [markdown]
# 이 그래프에 대한 해석과 가장 적절한 대응 방법으로 짝지어진 번호를 선택후 `답안14`변수에 저장하시오.
#
# (1)
# - **해석**: 훈련 손실(Training Loss)과 검증 손실(Validation Loss)이 모두 감소하고 있으므로, 모델이 안정적으로 학습되고 있다.
# - **대응**: 학습률(learning rate)을 높여 더 빠르게 최적점에 도달하도록 한다.
#
# (2)
# - **해석**: 검증 정확도(Validation Accuracy)가 훈련 정확도(Training Accuracy)보다 높으므로, 모델이 일반화 성능을 잘 확보했다.
# - **대응**: 모델의 복잡도를 낮추기 위해 레이어(layer)나 노드(node)의 수를 줄인다.
#
# (3)
# - **해석**: 훈련 정확도(Training Accuracy)는 계속 상승하지만 검증 정확도(Validation Accuracy)는 특정 시점부터 정체되거나 하락하는 **과적합(Overfitting)** 현상이 발생했다.
# - **대응**: `EarlyStopping` 콜백을 사용하여 검증 성능이 더 이상 개선되지 않을 때 학습을 조기 종료시킨다.
#
# (4)
# - **해석**: 훈련 데이터의 양이 부족하여 발생하는 **과소적합(Underfitting)** 현상이므로, 모델이 패턴을 충분히 학습하지 못했다.
# - **대응**: `Dropout` 레이어를 추가하거나 L1/L2 규제(regularization)를 적용하여 모델의 일반화 성능을 높인다.

# %%
# 여기에 코드를 작성하세요.

# %% [markdown]
# ---
